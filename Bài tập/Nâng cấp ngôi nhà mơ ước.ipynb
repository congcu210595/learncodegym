# %%
import turtle
t = turtle.Turtle()
turtle.bgcolor("Dodger blue")
t.pensize(3)

t.color("black","yellow")
t.begin_fill()
t.fd(150)
t.rt(90)
t.fd(130)
t.rt(90)
t.fd(300)
t.rt(90)
t.fd(130)
t.rt(90)
t.fd(150)
t.end_fill()

t.color("black","brown")
t.begin_fill()
t.fd(20)
t.lt(90)
t.fd(85)
t.lt(90)
t.fd(20)
t.lt(90)
t.fd(85)
t.lt(90)
t.end_fill()

t.color("black","orange")
t.begin_fill()
t.fd(50)
t.lt(135)
t.fd(141.42)
t.lt(90)
t.fd(141.42)
t.lt(135)
t.fd(200)
t.end_fill()

t.penup()
t.bk(30)
t.lt(90)
t.fd(100)
t.pendown()
t.fd(40)
t.lt(90)
t.penup()
t.fd(15)
t.lt(90)
t.fd(10)
t.pendown()
t.fd(25)

t.penup()
t.goto(35,-40)
t.pendown()
t.color("black","blue")
t.begin_fill()
for i in range(2):
    t.fd(90)
    t.rt(90)
    t.fd(70)
    t.rt(90)
t.end_fill()

t.penup()
t.goto(320,120)
t.pendown()
t.color("green","green")
t.begin_fill()
t.rt(45)
t.fd(60)
t.lt(135)
t.fd(84.82)
t.lt(135)
t.fd(60)
t.end_fill()

t.lt(135)
t.penup()
t.goto(320,77.57)
t.pendown()
t.color("green","green")
t.begin_fill()
t.rt(45)
t.fd(90)
t.lt(135)
t.fd(127.28)
t.lt(135)
t.fd(90)
t.end_fill()

t.lt(135)
t.penup()
t.goto(320,13.93)
t.pendown()
t.color("green","green")
t.begin_fill()
t.rt(45)
t.fd(120)
t.lt(135)
t.fd(169.7)
t.lt(135)
t.fd(120)
t.end_fill()

t.rt(135)
t.penup()
t.goto(320,-70.92)
t.pendown()
t.color("black","brown")
t.begin_fill()
t.fd(15)
t.rt(85)
t.fd(130)
t.rt(95)
t.fd(50)
t.rt(95)
t.fd(130)
t.rt(85)
t.fd(15)
t.end_fill()

t.rt(90)
t.penup()
t.goto(-200,-40)
t.pendown()
t.color("green","green")
t.begin_fill()
t.rt(45)
t.fd(30)
t.lt(135)
t.fd(42.41)
t.lt(135)
t.fd(30)
t.end_fill()

t.lt(135)
t.penup()
t.goto(-200,-61.2)
t.pendown()
t.color("green","green")
t.begin_fill()
t.rt(45)
t.fd(45)
t.lt(135)
t.fd(63.64)
t.lt(135)
t.fd(45)
t.end_fill()

t.lt(135)
t.penup()
t.goto(-200,-93.02)
t.pendown()
t.color("green","green")
t.begin_fill()
t.rt(45)
t.fd(60)
t.lt(135)
t.fd(85.4)
t.lt(135)
t.fd(60)
t.end_fill()

t.rt(135)
t.penup()
t.goto(-200,-135.45)
t.pendown()
t.color("black","brown")
t.begin_fill()
t.fd(7.5)
t.rt(85)
t.fd(65)
t.rt(95)
t.fd(25)
t.rt(95)
t.fd(65)
t.rt(85)
t.fd(7.5)
t.end_fill()
